# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
vidcap = cv2.VideoCapture('hand.mp4')
success,image = vidcap.read()
success = True
frames = []
while success:
  success,image = vidcap.read()
  if success:
      rescaled = cv2.resize(image, (0, 0), fx=0.5, fy=0.5)
      frames.append(cv2.cvtColor(rescaled, cv2.COLOR_BGR2GRAY))

# %%
frames = np.array(frames)
print(frames[0].shape)
print(len(frames))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-d43acd4c1fb3> in <module>()
#       1 frames = np.array(frames)
# ----> 2 print(frames[0].shape)
#       3 print(len(frames))
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
plt.imshow(frames[0],cmap='gray')
plt.show()
#print(frames[0][200,250])

# %%
plt.hist(frames[:,200,250])
plt.show()

# %%
# Out:
# (98, 360, 640)

# %%
result = np.zeros(frames[0].shape)
result1 = np.zeros(frames[0].shape)

for i in range(frames[0].shape[0]):
    for j in range(frames[0].shape[1]):
        val, indices = np.unique(frames[0:48,i,j], return_inverse=True)
        result1[i,j] = val[np.argmax(np.bincount(indices))]
        result[i,j] = np.mean(frames[0:48,i,j])# + x)/2

# %%
kernel = np.ones((8,8),np.float32)/25
result1_avg = result1
plt.imshow(result,cmap='gray')
plt.show()
plt.imshow(result1_avg,cmap='gray')
plt.show()
